# %%
import numpy as np

# %%
A = np.array([[0.2161, 0.1441],[1.2969, 0.8648]])
b = np.array([0.1440, 0.8642])
xt =  np.array([0.9911, -0.4870]) # Ansatz
x = np.array([2, -2])

# %%
b-A@xt # Al parecer buen Anzats. Parece cercano a la respuesta
# Out:
# array([-9.99999999e-09,  1.00000002e-08])

# %%
print(f"Ax={A@x} b={b} Ansatz={xt} Solución={x}")
print("¿Por qué?")
# Out:
# Ax=[0.144  0.8642] b=[0.144  0.8642] Ansatz=[ 0.9911 -0.487 ] Solución=[ 2 -2]
# ¿Por qué?
